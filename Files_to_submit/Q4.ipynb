# %%
# Render plots inline
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random as rand
from mlflow import log_metric, log_param, log_artifact
# adjust dimensions of plot area to make it look better
plt.rcParams['figure.figsize'] = (15, 5)

# %%
######## PART 4.1 ########

# %%
###### 4.1.(a) ######

# %%
attr_names = []
f = open('./files_for_q4/attributes.csv')
for line in f.readlines():
    attr_name = line.split()[1]
    attr_names.append(attr_name)

f.close()
list_attr_names = np.array(attr_names)

# %%
# initializations
communities_df = pd.read_csv('./files_for_q4/communities.csv', header=None, names=list_attr_names, index_col=False)
statistics_df = pd.read_csv('./files_for_q4/statistics.csv', sep=' ', index_col='Attribute')
means = statistics_df['Mean']
predictive_attr = list_attr_names[5:]
attrs_missing_val = statistics_df.loc[statistics_df['Missing'] != 0].index

# %%
for attr in attrs_missing_val:
    communities_df.loc[communities_df[attr] == '?', attr] = means[attr]

# %%
communities_df
# Out:
#       state county community           communityname  fold  population  \
# 0         8      ?         ?            Lakewoodcity     1        0.19
# 1        53      ?         ?             Tukwilacity     1        0.00
# 2        24      ?         ?            Aberdeentown     1        0.00
# 3        34      5     81440     Willingborotownship     1        0.04
# 4        42     95      6096       Bethlehemtownship     1        0.01
# 5         6      ?         ?       SouthPasadenacity     1        0.02
# 6        44      7     41500             Lincolntown     1        0.01
# 7         6      ?         ?               Selmacity     1        0.01
# 8        21      ?         ?           Hendersoncity     1        0.03
# 9        29      ?         ?             Claytoncity     1        0.01
# 10        6      ?         ?            DalyCitycity     1        0.13
# 11       36      ?         ?  RockvilleCentrevillage     1        0.02
# 12       25     21     44105             Needhamtown     1        0.03
# 13       55     87     30075          GrandChutetown     1        0.01
# 14        6      ?         ?           DanaPointcity     1        0.04
# 15       19    187     91370           FortDodgecity     1        0.03
# 16       36      1      1000              Albanycity     1        0.15
# 17       34     27     17650        Denvilletownship     1        0.01
# 18       18      ?         ?          Valparaisocity     1        0.02
# 19       42    129     66376       Rostravertownship     1        0.00
# 20        6      ?         ?             Modestocity     1        0.25
# 21       12     31         ?        Jacksonvillecity     1        1.00
# 22       41      ?         ?        KlamathFallscity     1        0.01
# 23       19    193     93926           SiouxCitycity     1        0.11
# 24        6      ?         ?              Delanocity     1        0.02
# 25        8      ?         ?              Goldencity     1        0.00
# 26        6      ?         ?             Gardenacity     1        0.06
# 27       39     29     61798           Perrytownship     1        0.01
# 28       54      ?         ?             Beckleycity     1        0.01
# 29        9      7     22490         EastHamptontown     1        0.00
# ...     ...    ...       ...                     ...   ...         ...
# 1964     36    119     49121         MountVernoncity    10        0.09
# 1965     18     97         ?        Indianapoliscity    10        1.00
# 1966      6      ?         ?         RedwoodCitycity    10        0.09
# 1967     25     17     76135            Westfordtown    10        0.01
# 1968     34     25     62430          RedBankborough    10        0.00
# 1969      6      ?         ?        SanFranciscocity    10        1.00
# 1970     45      ?         ?               Caycecity    10        0.00
# 1971      1      ?         ?             Decaturcity    10        0.06
# 1972      6      ?         ?            Redlandscity    10        0.08
# 1973     39      ?         ?           Englewoodcity    10        0.00
# 1974     37      ?         ?             Tarborotown    10        0.00
# 1975     53      ?         ?            Kirklandcity    10        0.05
# 1976     25     17      1605           Arlingtontown    10        0.06
# 1977     47      ?         ?           Maryvillecity    10        0.01
# 1978      9      1      4720              Betheltown    10        0.01
# 1979     34     39     61530              Rahwaycity    10        0.02
# 1980     25      5     69170             Tauntoncity    10        0.06
# 1981      9      9     35650              Hamdentown    10        0.07
# 1982     42    133     73168    SpringGardentownship    10        0.00
# 1983     13      ?         ?          ForestParkcity    10        0.01
# 1984     39     95     48342              Maumeecity    10        0.01
# 1985      1      ?         ?       AlexanderCitycity    10        0.01
# 1986      9      3     70550         Southingtontown    10        0.05
# 1987     44      7     11800        Burrillvilletown    10        0.01
# 1988     28      ?         ?            Columbuscity    10        0.02
# 1989     12      ?         ?       TempleTerracecity    10        0.01
# 1990      6      ?         ?             Seasidecity    10        0.05
# 1991      9      9     80070           Waterburytown    10        0.16
# 1992     25     17     72600             Walthamcity    10        0.08
# 1993      6      ?         ?             Ontariocity    10        0.20
#
#       householdsize  racepctblack  racePctWhite  racePctAsian  \
# 0              0.33          0.02          0.90          0.12
# 1              0.16          0.12          0.74          0.45
# 2              0.42          0.49          0.56          0.17
# 3              0.77          1.00          0.08          0.12
# 4              0.55          0.02          0.95          0.09
# 5              0.28          0.06          0.54          1.00
# 6              0.39          0.00          0.98          0.06
# 7              0.74          0.03          0.46          0.20
# 8              0.34          0.20          0.84          0.02
# 9              0.40          0.06          0.87          0.30
# 10             0.71          0.15          0.07          1.00
# 11             0.46          0.08          0.91          0.07
# 12             0.47          0.01          0.96          0.13
# 13             0.44          0.00          0.98          0.04
# 14             0.36          0.01          0.85          0.14
# 15             0.34          0.06          0.93          0.03
# 16             0.31          0.40          0.63          0.14
# 17             0.53          0.01          0.94          0.20
# 18             0.47          0.01          0.97          0.07
# 19             0.41          0.05          0.96          0.01
# 20             0.54          0.05          0.71          0.48
# 21             0.42          0.47          0.59          0.12
# 22             0.34          0.02          0.87          0.07
# 23             0.43          0.04          0.89          0.09
# 24             0.96          0.05          0.00          1.00
# 25             0.33          0.02          0.91          0.16
# 26             0.49          0.46          0.00          1.00
# 27             0.37          0.01          0.99          0.02
# 28             0.27          0.43          0.64          0.08
# 29             0.50          0.01          0.98          0.02
# ...             ...           ...           ...           ...
# 1964           0.45          1.00          0.08          0.11
# 1965           0.36          0.44          0.64          0.06
# 1966           0.41          0.07          0.74          0.39
# 1967           0.66          0.00          0.97          0.10
# 1968           0.24          0.51          0.53          0.11
# 1969           0.29          0.21          0.29          1.00
# 1970           0.37          0.38          0.69          0.04
# 1971           0.39          0.32          0.73          0.04
# 1972           0.49          0.07          0.69          0.27
# 1973           0.38          0.03          0.97          0.04
# 1974           0.41          0.62          0.51          0.02
# 1975           0.27          0.03          0.89          0.27
# 1976           0.29          0.03          0.93          0.18
# 1977           0.35          0.06          0.94          0.06
# 1978           0.54          0.02          0.94          0.13
# 1979           0.43          0.39          0.63          0.15
# 1980           0.43          0.04          0.93          0.03
# 1981           0.38          0.17          0.84          0.11
# 1982           0.47          0.02          0.98          0.03
# 1983           0.45          0.37          0.65          0.15
# 1984           0.43          0.01          0.98          0.03
# 1985           0.41          0.55          0.57          0.01
# 1986           0.52          0.02          0.97          0.04
# 1987           0.65          0.00          1.00          0.01
# 1988           0.41          1.00          0.21          0.02
# 1989           0.40          0.10          0.87          0.12
# 1990           0.96          0.46          0.28          0.83
# 1991           0.37          0.25          0.69          0.04
# 1992           0.51          0.06          0.87          0.22
# 1993           0.78          0.14          0.46          0.24
#
#              ...           LandArea  PopDens  PctUsePubTrans  PolicCars  \
# 0            ...               0.12     0.26            0.20       0.06
# 1            ...               0.02     0.12            0.45       0.16
# 2            ...               0.01     0.21            0.02       0.16
# 3            ...               0.02     0.39            0.28       0.16
# 4            ...               0.04     0.09            0.02       0.16
# 5            ...               0.01     0.58            0.10       0.16
# 6            ...               0.05     0.08            0.06       0.16
# 7            ...               0.01     0.33            0.00       0.16
# 8            ...               0.04     0.17            0.04       0.16
# 9            ...               0.00     0.47            0.11       0.16
# 10           ...               0.02     1.00            1.00       0.16
# 11           ...               0.01     0.63            1.00       0.16
# 12           ...               0.03     0.18            0.59       0.16
# 13           ...               0.08     0.04            0.00       0.16
# 14           ...               0.02     0.40            0.15       0.16
# 15           ...               0.04     0.15            0.04       0.16
# 16           ...               0.06     0.39            0.84       0.06
# 17           ...               0.03     0.09            0.21       0.16
# 18           ...               0.03     0.20            0.07       0.16
# 19           ...               0.09     0.03            0.05       0.16
# 20           ...               0.09     0.46            0.05       0.09
# 21           ...               1.00     0.07            0.15          1
# 22           ...               0.05     0.09            0.06       0.16
# 23           ...               0.16     0.12            0.07       0.04
# 24           ...               0.02     0.22            0.02       0.16
# 25           ...               0.02     0.15            0.16       0.16
# 26           ...               0.01     0.79            0.21       0.16
# 27           ...               0.04     0.09            0.00       0.16
# 28           ...               0.02     0.17            0.00       0.16
# 29           ...               0.10     0.02            0.08       0.16
# ...          ...                ...      ...             ...        ...
# 1964         ...               0.01     1.00            1.00       0.16
# 1965         ...               1.00     0.17            0.18       0.45
# 1966         ...               0.05     0.29            0.22       0.16
# 1967         ...               0.09     0.04            0.04       0.16
# 1968         ...               0.00     0.50            0.49       0.16
# 1969         ...               0.13     1.00            1.00       0.53
# 1970         ...               0.02     0.10            0.08       0.16
# 1971         ...               0.14     0.09            0.01       0.16
# 1972         ...               0.07     0.21            0.02       0.16
# 1973         ...               0.01     0.18            0.10       0.16
# 1974         ...               0.02     0.10            0.00       0.16
# 1975         ...               0.03     0.31            0.34       0.16
# 1976         ...               0.01     0.72            0.94       0.16
# 1977         ...               0.04     0.12            0.01       0.16
# 1978         ...               0.05     0.09            0.14       0.16
# 1979         ...               0.01     0.53            0.43       0.16
# 1980         ...               0.13     0.09            0.11       0.16
# 1981         ...               0.09     0.13            0.17       0.02
# 1982         ...               0.02     0.14            0.04       0.16
# 1983         ...               0.02     0.16            0.13       0.16
# 1984         ...               0.02     0.15            0.06       0.16
# 1985         ...               0.11     0.03            0.01       0.16
# 1986         ...               0.10     0.09            0.03       0.16
# 1987         ...               0.16     0.02            0.02       0.16
# 1988         ...               0.03     0.17            0.02       0.16
# 1989         ...               0.01     0.28            0.05       0.16
# 1990         ...               0.02     0.37            0.20       0.16
# 1991         ...               0.08     0.32            0.18       0.08
# 1992         ...               0.03     0.38            0.33       0.02
# 1993         ...               0.11     0.30            0.05       0.08
#
#       PolicOperBudg  LemasPctPolicOnPatr  LemasGangUnitDeploy  \
# 0              0.04                  0.9                  0.5
# 1              0.08                  0.7                 0.44
# 2              0.08                  0.7                 0.44
# 3              0.08                  0.7                 0.44
# 4              0.08                  0.7                 0.44
# 5              0.08                  0.7                 0.44
# 6              0.08                  0.7                 0.44
# 7              0.08                  0.7                 0.44
# 8              0.08                  0.7                 0.44
# 9              0.08                  0.7                 0.44
# 10             0.08                  0.7                 0.44
# 11             0.08                  0.7                 0.44
# 12             0.08                  0.7                 0.44
# 13             0.08                  0.7                 0.44
# 14             0.08                  0.7                 0.44
# 15             0.08                  0.7                 0.44
# 16             0.06                 0.91                  0.5
# 17             0.08                  0.7                 0.44
# 18             0.08                  0.7                 0.44
# 19             0.08                  0.7                 0.44
# 20             0.05                 0.88                  0.5
# 21             0.35                 0.73                    0
# 22             0.08                  0.7                 0.44
# 23             0.01                 0.81                    1
# 24             0.08                  0.7                 0.44
# 25             0.08                  0.7                 0.44
# 26             0.08                  0.7                 0.44
# 27             0.08                  0.7                 0.44
# 28             0.08                  0.7                 0.44
# 29             0.08                  0.7                 0.44
# ...             ...                  ...                  ...
# 1964           0.08                  0.7                 0.44
# 1965           0.19                  0.5                  0.5
# 1966           0.08                  0.7                 0.44
# 1967           0.08                  0.7                 0.44
# 1968           0.08                  0.7                 0.44
# 1969           0.62                 0.64                  0.5
# 1970           0.08                  0.7                 0.44
# 1971           0.08                  0.7                 0.44
# 1972           0.08                  0.7                 0.44
# 1973           0.08                  0.7                 0.44
# 1974           0.08                  0.7                 0.44
# 1975           0.08                  0.7                 0.44
# 1976           0.08                  0.7                 0.44
# 1977           0.08                  0.7                 0.44
# 1978           0.08                  0.7                 0.44
# 1979           0.08                  0.7                 0.44
# 1980           0.08                  0.7                 0.44
# 1981           0.01                 0.72                    0
# 1982           0.08                  0.7                 0.44
# 1983           0.08                  0.7                 0.44
# 1984           0.08                  0.7                 0.44
# 1985           0.08                  0.7                 0.44
# 1986           0.08                  0.7                 0.44
# 1987           0.08                  0.7                 0.44
# 1988           0.08                  0.7                 0.44
# 1989           0.08                  0.7                 0.44
# 1990           0.08                  0.7                 0.44
# 1991           0.06                 0.78                    0
# 1992           0.02                 0.79                    0
# 1993           0.04                 0.73                  0.5
#
#       LemasPctOfficDrugUn  PolicBudgPerPop  ViolentCrimesPerPop
# 0                    0.32             0.14                 0.20
# 1                    0.00              0.2                 0.67
# 2                    0.00              0.2                 0.43
# 3                    0.00              0.2                 0.12
# 4                    0.00              0.2                 0.03
# 5                    0.00              0.2                 0.14
# 6                    0.00              0.2                 0.03
# 7                    0.00              0.2                 0.55
# 8                    0.00              0.2                 0.53
# 9                    0.00              0.2                 0.15
# 10                   0.00              0.2                 0.24
# 11                   0.00              0.2                 0.08
# 12                   0.00              0.2                 0.06
# 13                   0.00              0.2                 0.09
# 14                   0.00              0.2                 0.21
# 15                   0.00              0.2                 0.30
# 16                   0.88             0.26                 0.49
# 17                   0.00              0.2                 0.07
# 18                   0.00              0.2                 0.15
# 19                   0.00              0.2                 0.03
# 20                   0.76             0.13                 0.34
# 21                   0.31             0.21                 0.69
# 22                   0.00              0.2                 0.21
# 23                   0.56             0.09                 0.63
# 24                   0.00              0.2                 0.31
# 25                   0.00              0.2                 0.12
# 26                   0.00              0.2                 0.84
# 27                   0.00              0.2                 0.10
# 28                   0.00              0.2                 0.49
# 29                   0.00              0.2                 0.02
# ...                   ...              ...                  ...
# 1964                 0.00              0.2                 0.60
# 1965                 0.44             0.21                 0.69
# 1966                 0.00              0.2                 0.30
# 1967                 0.00              0.2                 0.04
# 1968                 0.00              0.2                 0.19
# 1969                 0.64             0.35                 0.75
# 1970                 0.00              0.2                 0.53
# 1971                 0.00              0.2                 0.22
# 1972                 0.00              0.2                 0.30
# 1973                 0.00              0.2                 0.04
# 1974                 0.00              0.2                 0.52
# 1975                 0.00              0.2                 0.09
# 1976                 0.00              0.2                 0.08
# 1977                 0.00              0.2                 0.25
# 1978                 0.00              0.2                 0.04
# 1979                 0.00              0.2                 0.16
# 1980                 0.00              0.2                 0.28
# 1981                 0.62             0.15                 0.07
# 1982                 0.00              0.2                 0.03
# 1983                 0.00              0.2                 0.56
# 1984                 0.00              0.2                 0.14
# 1985                 0.00              0.2                 0.14
# 1986                 0.00              0.2                 0.02
# 1987                 0.00              0.2                 0.04
# 1988                 0.00              0.2                 0.19
# 1989                 0.00              0.2                 0.09
# 1990                 0.00              0.2                 0.45
# 1991                 0.91             0.28                 0.23
# 1992                 0.22             0.18                 0.19
# 1993                 1.00             0.13                 0.48
#
# [1994 rows x 128 columns]

# %%
###### 4.1.(b) ######
"""
abs(mean (+ or - or 0)*SD)
[if this new value exceeds 1, make it equal to the mean]
"""
# Out:
# '\nabs(mean (+ or - or 0) some percentage*2*SD)\n[if this new value exceeds 1, make it equal to the mean]\n'

# %%
###### 4.1.(c) ######
"""
This can be used to fill in the missing values. It would
provide some degree of randomness to our data instead of 
filling in the same constant value. Since we have a lot
of empty data points, taking SD will give us some
range. It would better simulate the absent data points and 
our data set would be much closer to a data set wherein 
all values were filled in. 
"""
# Out:
# '\nThis can be used to fill in the missing values. It would\nprovide some degree of randomness to our data instead of \nfilling in the same constant value. Since we have a lot\nof empty data points, taking SD will give us some\nrange. It would better simulate the absent data points and \nour data set would be much closer to a data set wherein \nall values were filled in. \n'

# %%
comm_df = pd.read_csv('./files_for_q4/communities.csv', header=None, names=list_attr_names, index_col=False)

# %%
for attr in attrs_missing_val:
    for i in range(len(comm_df)):
        if comm_df[attr][i] == '?':
            add_or_subtract = rand.randint(-1, 1)
            new_val = abs(means[attr] + add_or_subtract*statistics_df['SD'][attr])
            if new_val >= 1:
                new_val = means[attr]
            # comm_df.set_value(i, attr, new_val)
            comm_df.at[i, attr] = new_val

# %%
###### 4.1.(d) ######

# %%
comm_df.to_csv('communities_filled.csv')

# %%
######## PART 4.2 ########

# %%
def split_and_make_dfs(df, i):
    df = df.drop(['state', 'county', 'community', 'communityname', 'fold'], axis=1)
    df = df.astype('float64')
    train_df = df.sample(frac=0.8)
    test_df = df.loc[~df.index.isin(train_df.index)]
    train_filename = "CandC−train%d.csv" % (i)
    test_filename = "CandC−test%d.csv" % (i)
    train_df.to_csv(train_filename)
    test_df.to_csv(test_filename)
    return [train_df, test_df]

# %%
def find_params_vector(data_matrix, y_values):
    """
    Finds the vector of coefficients or, the paramter
    vector that will minimize our loss function. The closed
    form solution for w, where w is the parameter vector, is - 
            w* = [{(X^T)X}^-1](X^T)y
            where -
                X = parameter 'data_matrix' mentioned below
                y = parameter 'y_values' mentioned below
                
    The closed form solution can also be seen by running the following - 
        "Image(filename='closed_form_soln.png')".

    Arguments:
        data_matrix - matrix generated by the make_data_matrix()
                        method using the input data points - An 
                        Nx(degree+1) matrix where ith feature/column
                        is the N data points raised to the power i
        y_values - list of output data points from given dataset
    Returns:
        A vector containing the values for the parameters that
        minimize the error function (i.e. solution obtained for w*)
    """
    data_product = (data_matrix.T).dot(data_matrix)
    inv_product = np.linalg.inv(data_product)
    params_vector = (inv_product.dot(data_matrix.T)).dot(y_values)
    return params_vector

# %%
def find_predictions(data_matrix, params_vector):
    """
    Gives a Nx1 vector where each entry is the predicted
    value for y, which is calculated using the parameters vector
    obtained from the find_params_vector() method and a row/example
    from the data matrix.

    Arguments:
        data_matrix - matrix generated by the make_data_matrix()
                        method using the input data points - An 
                        Nx(degree+1) matrix where ith feature/column
                        is the N data points raised to the power i
        params_vector - vector containing the values for the parameters that
                        minimize the error function (i.e. solution obtained for w*)
                        from the find_params_vector() method
    """
    return np.array([row.dot(params_vector) for row in data_matrix])

# %%
def find_mse(data_matrix, params_vector, y_values):
    """
    Steps for finding the Mean Square Error - 
    1. Get the prediction values for the input
        data points based on the model found.
    2. Calculate the error vector by differencing
        the vector containing target values and 
        the vector containing the predicted values.
    3. Take the square of the errors found and sum them 
        by taking dot product of the error vector with itself.
    4. Calculate the MSE by dividing the sum of the
        squares of errors with the number of input data points.

    Arguments:
        data_matrix - matrix generated by the make_data_matrix()
                        method using the input data points - An 
                        Nx(degree+1) matrix where ith feature/column
                        is the N data points raised to the power i
        params_vector - vector containing the values for the parameters that
                        minimize the error function (i.e. solution obtained for w*)
                        from the find_params_vector() method
        y_values - list of output data points from given dataset
    Returns:
        Mean Square Error of model for given data set
    """
    y_predictions = find_predictions(data_matrix, params_vector)
    error = y_values - y_predictions
    error_square = error.dot(error)
    mse = error_square/len(y_values)
    return mse

# %%
def do_cross_validation(df):
    list_test_mses = []
    params_over_runs = []
    for i in range(1, 6):
        dataframes = split_and_make_dfs(df, i)
        train_df = dataframes[0]
        test_df = dataframes[1]

        train_matrix = np.array(train_df.drop('ViolentCrimesPerPop', axis=1).values)
        train_y = np.array(train_df['ViolentCrimesPerPop'].values)

        test_matrix = np.array(test_df.drop('ViolentCrimesPerPop', axis=1).values)
        test_y = np.array(test_df['ViolentCrimesPerPop'].values)

        params = find_params_vector(train_matrix, train_y)
        test_mse = find_mse(test_matrix, params, test_y)
        list_test_mses.append(test_mse)
        params_over_runs.append(params)
    
    return [list_test_mses, params_over_runs]

# %%
list_test_mses, params_over_runs = do_cross_validation(comm_df)

# %%
list_test_mses
# Out:
# [0.019595807858942525,
#  0.0159322229173019,
#  0.016652298539168643,
#  0.01701636814088926,
#  0.015806910555271704]

# %%
average_test_mse = sum(list_test_mses)/len(list_test_mses)

# %%
print(average_test_mse)
# Out:
# 0.017000721602314806

# %%
print(params_over_runs)
# Out:
# [array([ 7.70031533e-01, -4.59939204e-02,  1.78401924e-01, -5.87562012e-02,
#        -1.06392808e-02,  1.31270159e-01,  2.01304752e-01, -1.04117927e-01,
#        -2.55321340e-01,  1.90130584e-01, -7.74959836e-01,  7.19054912e-02,
#        -1.05989025e-01, -8.78980684e-02,  4.50594032e-02, -1.58332100e-01,
#         1.69680531e-01,  2.51197329e-02, -7.53806434e-02,  3.00076273e-01,
#         5.05581003e-02, -3.48540061e-01, -2.56415083e-02, -3.47641615e-02,
#         1.42452683e-02,  2.13342352e-02,  3.96463558e-02, -5.36056830e-02,
#        -1.25897883e-01, -1.43173935e-02, -7.84112557e-03,  6.17505624e-02,
#         7.27452694e-03,  2.92368557e-01, -6.17905543e-02, -2.70933475e-02,
#         5.85865920e-02,  9.96365734e-02,  4.09669532e-01,  2.61679176e-01,
#         1.32292828e-01, -3.86807010e-01, -1.88555649e-01,  7.56788304e-02,
#        -2.26750277e-01, -7.61361813e-02, -1.14157491e-02,  1.59742112e-02,
#        -1.44265262e-01, -9.30551031e-02,  1.57554195e-01, -1.99070028e-01,
#         6.08317176e-02,  2.01099050e-02, -7.48663688e-02,  2.55717564e-02,
#        -4.21135470e-02, -1.66869832e-01,  3.31907020e-01, -1.18715690e-01,
#         6.93251307e-02, -2.01451546e-01, -6.40608243e-03, -1.51645795e-01,
#         6.22016461e-01,  3.72290759e-04, -1.94478093e-01, -6.67343917e-01,
#         1.70120014e-01,  1.27964792e-01,  4.26003636e-02,  1.51269885e-01,
#        -4.42467430e-02,  5.27319308e-01,  4.32756708e-02, -6.00390447e-02,
#        -1.16545577e-03,  1.98435438e-03, -1.40634895e-02, -3.10923249e-01,
#         1.61664066e-01,  5.31308136e-02, -2.39792903e-01, -5.71370558e-02,
#        -6.29626157e-02,  3.93765238e-01,  5.02415183e-02, -4.51742852e-02,
#        -7.47813625e-02,  1.86659103e-01,  2.14847813e-01,  1.80107025e-01,
#        -2.86100891e-03, -4.55741845e-03,  2.84962686e-02,  1.67640398e-02,
#        -1.74611490e-03, -2.69353265e-02,  7.34515901e-03,  2.72399843e-02,
#         3.34150342e-02,  2.15733420e-02,  1.41995219e-02,  1.77420868e-02,
#        -1.34411757e-02, -2.06073216e-02, -2.17577504e-03,  1.35494816e-02,
#         1.40256792e-02,  2.92486688e-02, -1.01757734e-02,  1.59981183e-03,
#         2.46309623e-03,  2.04845340e-02,  3.93272052e-04, -4.02584889e-02,
#         3.64577383e-02, -3.09694105e-02, -1.75140899e-02, -2.91862322e-03,
#         4.49969242e-02, -4.34044727e-02]), array([-1.58528255e-02, -5.29700096e-02,  2.41220553e-01, -3.14977167e-02,
#         1.95519300e-02,  1.39823721e-01,  1.78045371e-01, -9.98777914e-02,
#        -2.38075942e-01,  1.32407507e-01, -6.26737687e-02,  4.35464283e-02,
#        -1.73014244e-01, -9.80043881e-02,  5.72091397e-02, -1.19166474e-01,
#         1.92233804e-01,  1.87167913e-02, -7.71818515e-02,  2.64551789e-01,
#         9.54635703e-02, -3.86462081e-01, -3.13309039e-02, -3.33225048e-02,
#         3.68482549e-02,  4.66149234e-02,  2.93275871e-02,  3.20354703e-02,
#        -1.50664406e-01, -1.13602898e-01,  1.11972990e-01,  8.79261778e-02,
#        -3.45033745e-02,  2.63253121e-01, -6.88530094e-02, -2.88078620e-02,
#         9.49173751e-02,  1.35820942e-01,  6.06264178e-01,  2.42661175e-01,
#         3.13606669e-01, -7.48860557e-01, -1.44067622e-01, -2.78541435e-02,
#        -1.62915843e-01, -5.76389623e-02, -2.30219275e-02,  3.48872126e-02,
#        -1.66902354e-01, -1.36842109e-01,  1.27472463e-01, -1.74539733e-01,
#         7.76557219e-03,  4.03840852e-02, -1.28267946e-02, -2.33711491e-02,
#         9.55438865e-02, -3.91009112e-01,  2.50381909e-01,  5.28457284e-02,
#         7.56558724e-02, -1.08839679e-01, -1.10284570e-01, -8.36125330e-02,
#         6.93577052e-01,  5.74180391e-03, -2.61599659e-01, -7.37149730e-01,
#         2.03315929e-01,  1.65508467e-01,  4.74383697e-02,  1.88543944e-01,
#        -4.25040378e-02,  6.29946168e-01,  5.31683282e-02, -5.67323487e-02,
#        -1.74174086e-02,  1.15977733e-02, -2.88264604e-02, -3.57344691e-01,
#         1.58325573e-01,  1.39497991e-01, -2.50801584e-01, -3.48360342e-02,
#        -1.01301964e-01,  4.15183469e-01,  7.14089740e-02, -3.22647309e-02,
#        -8.56253923e-02,  1.51913601e-01,  1.72747156e-01,  1.33632996e-01,
#         3.16065785e-02,  1.49827384e-02,  2.39672409e-03, -2.43742555e-02,
#        -2.58241842e-02, -3.94783106e-02, -1.98594113e-02,  3.48804126e-02,
#         3.49152832e-02,  1.86568766e-02,  2.31358591e-02, -1.57596807e-03,
#        -2.93208319e-02, -2.60507462e-02,  7.92372044e-03,  4.38837320e-03,
#         1.15562728e-02,  3.80202010e-02,  2.50876537e-02, -1.84073157e-02,
#         7.24258505e-03,  5.58580656e-03,  1.27230111e-02, -4.75258248e-02,
#         2.33178446e-02, -4.06703730e-03,  3.49630016e-04,  2.23174179e-03,
#         4.24624029e-02, -6.71380439e-02]), array([ 3.83139506e-02, -4.28209893e-02,  2.41486543e-01,  1.17024739e-02,
#         2.45626352e-02,  1.29771079e-01,  1.30461765e-01,  4.93666388e-02,
#        -2.69237880e-01,  2.22693486e-01, -1.51429093e-01,  4.88506857e-02,
#        -9.77321867e-02, -1.56073519e-01,  4.02224260e-02, -1.26650547e-01,
#         1.01520990e-01, -1.56021706e-02, -8.81804395e-02,  2.58049353e-01,
#         1.47078238e-01, -4.17584163e-01, -3.51032095e-02, -3.31910371e-02,
#         3.48633047e-02,  3.70493884e-02,  3.11311249e-02,  3.72594914e-02,
#        -1.24100292e-01, -8.36688417e-02,  4.33919120e-02,  1.05524644e-01,
#         9.92810271e-03,  2.66076815e-01, -6.60752201e-02, -3.68137640e-02,
#         1.09465155e-01,  1.00308253e-01,  3.36624615e-01,  2.39434276e-01,
#         2.33861171e-02, -2.27762861e-01, -1.32332493e-01,  1.07968378e-01,
#        -2.50081680e-01, -7.09926562e-02, -2.73704201e-02,  6.52069699e-02,
#        -1.78486952e-01, -1.16610600e-03,  1.45886877e-01, -1.76675206e-01,
#         1.35481042e-02,  3.59314591e-02, -4.34058360e-02,  6.84933509e-04,
#        -6.19024453e-02, -9.76594750e-02,  2.23730853e-01, -6.46172316e-02,
#         2.63902885e-02, -1.87321680e-01, -9.98737521e-02, -1.20859362e-01,
#         8.26035243e-01, -1.55504325e-01, -2.10324124e-01, -5.93885770e-01,
#         1.93958867e-01,  1.38008421e-01,  3.80929989e-02,  1.29916331e-01,
#        -7.92265450e-02,  4.95157098e-01,  6.32533380e-02, -8.17173577e-02,
#        -1.57005914e-02,  2.14492589e-02, -1.25451487e-02, -2.55043004e-01,
#         4.57846853e-02,  1.44623373e-01, -2.39520376e-01, -1.32555953e-01,
#        -2.69394498e-02,  3.91426052e-01,  4.26473774e-02, -4.55261631e-02,
#        -7.24941877e-02,  1.62886408e-01,  1.19714796e-01,  1.78006669e-01,
#         1.23683526e-02, -4.28406219e-02,  3.45867147e-02,  2.20226278e-02,
#        -7.08364957e-03, -5.31661439e-02, -4.34978295e-03,  4.59829353e-02,
#         7.46426955e-03,  1.34467767e-02,  2.39349284e-02, -5.34603475e-04,
#        -2.04128724e-02, -1.19678177e-02,  6.81585132e-03,  2.93859697e-02,
#         3.83679015e-03,  3.05210960e-02,  1.96305738e-02, -1.73952740e-02,
#        -4.29845359e-03,  1.28209940e-02,  2.81308567e-02, -4.18377493e-02,
#         4.18712369e-02, -6.15224670e-02, -8.36715436e-03,  4.33391000e-03,
#         2.59918804e-02, -3.33925250e-02]), array([-1.19176254e-01, -1.30652250e-01,  1.89978193e-01, -4.29885362e-02,
#         3.17134860e-03,  1.36229802e-01,  2.23435664e-01, -3.66167377e-02,
#        -2.94243251e-01,  1.28358008e-01,  7.06358285e-02,  3.19319483e-02,
#         3.62925531e-03, -9.68035648e-02,  4.19654359e-02, -1.77613895e-01,
#         1.63343259e-01,  8.92565630e-02, -6.08594958e-02,  1.55004840e-01,
#         5.21520099e-02, -3.14924789e-01, -2.88062995e-02, -2.92696131e-02,
#         4.17958248e-02,  3.07148885e-02,  2.29396166e-02, -1.05659883e-01,
#        -1.02892601e-01, -7.25991138e-02,  1.80849495e-02,  1.26218126e-01,
#        -2.23490897e-02,  2.51603206e-01, -5.91395980e-02, -6.48512348e-02,
#         2.25479021e-02,  7.81667558e-02,  5.34280590e-01,  2.39089871e-01,
#         3.21048299e-01, -7.47846277e-01, -1.79182014e-01, -7.61377618e-03,
#        -2.05137474e-01,  2.52093516e-02,  8.87715658e-03,  6.84297986e-02,
#        -1.69152324e-01, -6.29891946e-02,  1.82742915e-01, -1.43409704e-01,
#        -1.56783990e-03,  6.59940589e-02, -1.38565656e-01,  9.19855119e-02,
#         5.05046116e-02, -1.45653679e-01,  3.94539781e-01, -3.82136980e-01,
#         5.11692937e-02, -2.30836985e-01,  9.05641391e-02, -2.79542200e-01,
#         7.42916603e-01, -9.10958052e-02, -1.98257649e-01, -5.42990258e-01,
#         2.14326932e-01,  1.69959848e-01,  2.59600782e-02,  1.70262340e-01,
#        -5.49491864e-02,  4.58247583e-01,  5.26705866e-02, -7.28637139e-02,
#        -1.94582093e-02,  4.61288749e-03, -1.05255531e-02, -4.26871436e-01,
#         3.33984605e-01, -5.96713221e-03, -2.73883970e-01, -7.67649970e-02,
#        -7.45878066e-02,  4.21356386e-01,  4.08012198e-02, -3.16055956e-02,
#        -8.86287682e-02,  2.07129661e-01,  1.88141274e-01,  2.66441947e-01,
#         3.38318582e-02, -1.44708261e-02,  4.36966981e-02,  1.20650914e-02,
#         4.84892771e-03, -4.40033441e-02,  3.08770807e-02,  3.86241272e-02,
#         6.78021868e-04,  2.33320310e-02,  3.88649458e-02, -3.54607458e-03,
#        -2.23699291e-02, -1.22389230e-02, -7.09175749e-03,  9.93512688e-03,
#         2.81700242e-04,  2.48433676e-02, -1.16877101e-02, -7.34120341e-03,
#        -1.00573565e-03,  4.40202515e-02,  1.90004198e-02, -3.17218968e-02,
#         3.81287753e-02, -7.27516666e-03, -1.23969687e-02,  1.79904291e-04,
#         2.51737149e-02, -3.86419565e-02]), array([ 9.84360925e-02, -6.55231659e-02,  2.77618805e-01,  2.48908983e-02,
#         3.62320696e-02,  1.02077657e-01,  1.49964593e-01, -1.14464115e-01,
#        -2.21414023e-01,  1.22899054e-01, -8.22376307e-02,  4.97695330e-02,
#        -2.11446481e-01, -6.91114629e-02,  5.02083694e-02, -1.66699773e-01,
#         1.48340069e-01,  2.28984477e-02, -4.88465094e-02,  2.64955399e-01,
#         9.90350722e-02, -3.47612657e-01, -3.59634988e-02, -3.39447888e-02,
#         2.41492419e-02,  5.39898917e-02,  2.09145336e-02, -2.36270193e-02,
#        -1.36023331e-01, -1.21975326e-01,  1.15118535e-01,  1.05963102e-01,
#         1.80486489e-02,  2.82597686e-01, -6.08069550e-02, -2.79909091e-02,
#         8.04735117e-02,  1.06629605e-01,  4.53516458e-01,  2.53570700e-01,
#         1.36803720e-01, -4.96344221e-01, -8.68376276e-02, -7.70595112e-02,
#        -1.09825386e-01, -4.82334379e-02, -2.66499395e-02,  7.97247735e-02,
#        -2.38490461e-01, -9.78070605e-02,  1.18481896e-01, -1.61191096e-01,
#         3.03070411e-02,  5.86263804e-02, -9.22221757e-02,  2.90249529e-02,
#        -9.44652820e-02, -1.34558648e-01,  4.30155277e-01, -2.77070279e-01,
#         9.19665620e-02, -7.80185361e-02, -5.45020094e-03, -1.77583595e-01,
#         6.67550875e-01, -1.24637514e-01, -2.34416205e-01, -5.66633298e-01,
#         2.07863349e-01,  1.05623379e-01,  2.43070731e-02,  1.12204754e-01,
#        -5.78372553e-02,  4.91861872e-01,  5.20341256e-02, -4.68234630e-02,
#        -9.29829494e-03,  1.35659377e-02, -1.86281541e-02, -4.75217101e-02,
#        -1.07978008e-01,  1.25389943e-01, -2.36501194e-01, -1.11894965e-01,
#        -6.31070678e-02,  4.43590274e-01,  4.38545797e-02, -5.77505152e-02,
#        -9.33398170e-02,  1.91970363e-01,  1.51170145e-01,  2.15562449e-01,
#         4.55164497e-03, -7.25849897e-02,  4.29986052e-02,  1.89629911e-02,
#         2.68261781e-03, -3.09528947e-02,  2.21952511e-02,  4.26285650e-02,
#        -1.34273930e-03,  1.75230678e-02,  2.50632042e-02,  1.04198172e-02,
#        -2.02988633e-02, -1.75610957e-02, -2.72769865e-04,  4.65774008e-02,
#         1.36882929e-02,  3.45211251e-02, -4.24867997e-03, -8.17647068e-03,
#        -1.78007429e-03,  1.09020195e-02, -2.78111388e-04, -2.50684341e-02,
#         2.59946133e-02, -1.76168193e-02, -6.00443778e-03,  3.17786703e-03,
#         2.69151648e-02, -5.24603750e-02])]

# %%
with open('params.txt', 'w') as f:
    for p in params_over_runs:
        f.write("%s\n" % p)
